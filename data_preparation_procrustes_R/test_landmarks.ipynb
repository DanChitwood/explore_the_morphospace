# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./0.passiflora_original.csv")

# %%
df.head()
# Out:
#    species  ontogeny  total  heteroblasty         x1          y1         x2  \
# 0  actinia         1     17            17   1.939415  414.812913  -7.047279
# 1  actinia         2     17            16 -27.972095  433.154746 -27.127051
# 2  actinia         3     17            15 -43.242816  430.053913 -39.277936
# 3  actinia         4     17            14 -36.082509  416.832663 -30.527203
# 4  actinia         5     17            13  -7.724386  362.852233 -18.024917
#
#            y2         x3          y3  ...         x11          y11  \
# 0  385.719915  28.429685  371.115922  ... -108.831734 -1510.662028
# 1  417.953521 -17.138482  393.213241  ...   28.713845 -1468.443026
# 2  409.976781 -34.239161  376.468073  ...  120.698695 -1462.301694
# 3  394.236217 -19.829324  359.869763  ...  -58.899860 -1385.313503
# 4  347.266408 -16.965580  316.096657  ...   82.426785 -1493.947554
#
#           x12         y12         x13         y13         x14         y14  \
# ...

# %%
# Out:
# 1.939414673

# %%
one_leaf = df.iloc[3000]


plt.plot([one_leaf["x6"],one_leaf["x15"]], [one_leaf["y6"],one_leaf["y15"]])
plt.plot([one_leaf["x15"],one_leaf["x5"]], [one_leaf["y15"],one_leaf["y5"]])
plt.plot([one_leaf["x5"],one_leaf["x13"]], [one_leaf["y5"],one_leaf["y13"]])
plt.plot([one_leaf["x13"],one_leaf["x4"]], [one_leaf["y13"],one_leaf["y4"]])
plt.plot([one_leaf["x4"],one_leaf["x11"]], [one_leaf["y4"],one_leaf["y11"]])
plt.plot([one_leaf["x11"],one_leaf["x3"]], [one_leaf["y11"],one_leaf["y3"]])

plt.plot([one_leaf["x15"],one_leaf["x14"]], [one_leaf["y15"],one_leaf["y14"]])
plt.plot([one_leaf["x14"],one_leaf["x13"]], [one_leaf["y14"],one_leaf["y13"]])
plt.plot([one_leaf["x13"],one_leaf["x12"]], [one_leaf["y13"],one_leaf["y12"]])
plt.plot([one_leaf["x12"],one_leaf["x11"]], [one_leaf["y12"],one_leaf["y11"]])

plt.gca().set_aspect("equal")
